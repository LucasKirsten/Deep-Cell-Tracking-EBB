# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasKirsten/Deep-Cell-Tracking-EBB/blob/master/ISBI_Cell_Tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install anaconda (this will restart the runtime)
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# download the code and model weights
# !gdown 1u_p1rhUmxyfQ9fDnoABKUcSNEPBiqmvm
# !unzip SW.zip
# Out:
# Access denied with the following error:
#
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=1u_p1rhUmxyfQ9fDnoABKUcSNEPBiqmvm
#
# unzip:  cannot find or open SW.zip, SW.zip.zip or SW.zip.ZIP.

# %%
# setup environment
# %cd SW
# !bash setup.sh

# restart kernel
import os
os.kill(os.getpid(), 9)

# %%
# download datasets
# !wget http://data.celltrackingchallenge.net/training-datasets/Fluo-N2DH-GOWT1.zip
# !unzip Fluo-N2DH-GOWT1.zip

# %%
# run inference
# %cd SW
# !bash Fluo-N2DH-GOWT1-01.sh
# Out:
# [Errno 2] No such file or directory: 'SW'
# /content/SW
# ISBI_inferece.sh: line 9: /etc/profile.d/conda.sh: No such file or directory
# Converting images to jpg: 100% 92/92 [00:02<00:00, 36.69it/s]
# /workdir/Fluo-N2DH-GOWT1/01
# MEAN:  4.415305137634277
# STD:  14.490250382655713
# /content
# model restore from : /workdir/SW/RotationDetection/output/trained_weights/R2CNN_Fluo-N2DH-GOWT1-all_smooth_l1_loss/UFRGS_CELL_1class_100303model.ckpt
#
# **********
# Restored model
# /workdir/SW/RotationDetection/output/trained_weights/R2CNN_Fluo-N2DH-GOWT1-all_smooth_l1_loss/UFRGS_CELL_1class_100303model.ckpt
# **********
#   0% 0/92 [00:00<?, ?it/s]no CUDA-capable device is detected
# no CUDA-capable device is detected
# no CUDA-capable device is detected
# no CUDA-capable device is detected
# no CUDA-capable device is detected
# no CUDA-capable device is detected
# no CUDA-capable device is detected
# no CUDA-capable device is detected
# ...

# %%
# %cd /content/SW/RotationDetection/track_by_detection/evaluation/Linux
# !sudo chmod 777 ./TRAMeasure
# !./TRAMeasure /workdir/Fluo-N2DH-GOWT1 01 3
# Out:
# /content/SW/RotationDetection/track_by_detection/evaluation/Linux
# TRA measure: 0.993780
